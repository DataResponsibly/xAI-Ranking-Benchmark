# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
atp_time = pd.read_csv("results/time-experiment-ATP.csv", index_col=0)
atp_time.head()
# Out:
#   dataset  n_observations approach       parameter  parameter_value  \
# 0     ATP              86     rank             NaN              NaN
# 1     ATP              86     rank  coalition_size              1.0
# 2     ATP              86     rank  coalition_size              2.0
# 3     ATP              86     rank  coalition_size              3.0
# 4     ATP              86     rank  coalition_size              4.0
#
#     avg_time     time_0     time_1     time_2  agreement_kendall_0  ...  \
# 0  27.387376  27.427300  27.338099  27.396730                  NaN  ...
# 1   5.156870   5.165976   5.152693   5.151941             0.931783  ...
# 2  13.710754  13.689726  13.698786  13.743750             0.954264  ...
# 3  22.304398  22.270164  22.357620  22.285410             0.962791  ...
# 4  26.601693  26.619284  26.577720  26.608076             0.979070  ...
#
#    agreement_kendall_2  agreement_jaccard2_0  agreement_jaccard2_1  \
# 0                  NaN                   NaN                   NaN
# 1             0.931783              0.930233              0.930233
# 2             0.954264              0.953488              0.953488
# 3             0.962791              0.961240              0.961240
# 4             0.979070              0.976744              0.976744
#
#    agreement_jaccard2_2  agreement_euclidean_0  agreement_euclidean_1  \
# 0                   NaN                    NaN                    NaN
# 1              0.930233               0.961702               0.961702
# 2              0.953488               0.977033               0.977033
# 3              0.961240               0.986008               0.986008
# 4              0.976744               0.991244               0.991244
#
#    agreement_euclidean_2  fidelity_0  fidelity_1  fidelity_2
# 0                    NaN    0.067334    0.067334    0.067334
# 1               0.961702   14.791842   14.791842   14.791842
# 2               0.977033   11.180178   11.180178   11.180178
# 3               0.986008    7.467920    7.467920    7.467920
# 4               0.991244    3.748490    3.748490    3.748490
#
# [5 rows x 21 columns]

# %%
atp_time[atp_time['parameter']=="sample_size"]
# Out:
#    dataset  n_observations approach    parameter  parameter_value   avg_time  \
# 6      ATP              86     rank  sample_size              8.0   4.103827
# 7      ATP              86     rank  sample_size             17.0   6.788403
# 8      ATP              86     rank  sample_size             25.0   9.205796
# 9      ATP              86     rank  sample_size             34.0  11.932899
# 10     ATP              86     rank  sample_size             43.0  14.623444
# 11     ATP              86     rank  sample_size             51.0  16.989299
# 12     ATP              86     rank  sample_size             60.0  19.677545
# 13     ATP              86     rank  sample_size             68.0  22.117268
# 14     ATP              86     rank  sample_size             77.0  24.763907
# 15     ATP              86     rank  sample_size             86.0  27.450754
# 46     ATP              86     flip  sample_size              8.0   0.904677
# 47     ATP              86     flip  sample_size             17.0   1.012217
# 48     ATP              86     flip  sample_size             25.0   1.138535
# 49     ATP              86     flip  sample_size             34.0   1.236122
# 50     ATP              86     flip  sample_size             43.0   1.338366
# 51     ATP              86     flip  sample_size             51.0   1.437225
# 52     ATP              86     flip  sample_size             60.0   1.521806
# 53     ATP              86     flip  sample_size             68.0   1.608583
# 54     ATP              86     flip  sample_size             77.0   1.705746
# 55     ATP              86     flip  sample_size             86.0   1.805481
#
#        time_0     time_1     time_2  agreement_kendall_0  ...  \
# 6    4.068768   4.122202   4.120512             0.894574  ...
# 7    6.787508   6.757428   6.820271             0.940310  ...
# 8    9.252857   9.186560   9.177970             0.943411  ...
# 9   11.975079  11.979929  11.843689             0.930233  ...
# 46               0.995345   21.893338   21.889123   21.892805
# 47               0.996921   21.891872   21.891986   21.893855
# 48               0.997617   21.892426   21.891791   21.892124
# 49               0.998066   21.891570   21.892111   21.892037
# 50               0.998358   21.891915   21.892104   21.891464
# 51               0.998607   21.891522   21.892480   21.891549
# 52               0.998930   21.891757   21.892371   21.892019
# 53               0.999190   21.892100   21.892696   21.891915
# 54               0.999449   21.892127   21.891956   21.892014
# 55               1.000000   21.892104   21.892104   21.892104
#
# [20 rows x 21 columns]

# %%
atp_time.columns
# Out:
# Index(['dataset', 'n_observations', 'approach', 'parameter', 'parameter_value',
#        'avg_time', 'time_0', 'time_1', 'time_2', 'agreement_kendall_0',
#        'agreement_kendall_1', 'agreement_kendall_2', 'agreement_jaccard2_0',
#        'agreement_jaccard2_1', 'agreement_jaccard2_2', 'agreement_euclidean_0',
#        'agreement_euclidean_1', 'agreement_euclidean_2', 'fidelity_0',
#        'fidelity_1', 'fidelity_2'],
#       dtype='object')

# %%
# average fidelity
atp_time['average_fidelity'] = atp_time[['fidelity_0', 'fidelity_1', 'fidelity_2']].mean(axis=1)

# average agreement
atp_time['average_agreement_kendall'] = atp_time[['agreement_kendall_0', 'agreement_kendall_1', 'agreement_kendall_2']].mean(axis=1)
atp_time['average_agreement_jaccard'] = atp_time[['agreement_jaccard2_0', 'agreement_jaccard2_1', 'agreement_jaccard2_2']].mean(axis=1)
atp_time['average_agreement_euclidean'] = atp_time[['agreement_euclidean_0', 'agreement_euclidean_1', 'agreement_euclidean_2']].mean(axis=1)

# %%
atp_time[atp_time['parameter'] == 'sample_size']['parameter_value'].unique()
# Out:
# array([ 8., 17., 25., 34., 43., 51., 60., 68., 77., 86.])

# %%
atp_time[atp_time['parameter'] == 'coalition_size']['parameter_value'].unique()
# Out:
# array([1., 2., 3., 4., 5.])

# %%
threads_data = atp_time[atp_time['parameter'] == 'n_jobs']

plt.figure(figsize=(7, 4))

approaches = threads_data['approach'].unique()

for approach in approaches:
    approach_data = threads_data[threads_data['approach'] == approach]
    plt.plot(approach_data['parameter_value'], approach_data['avg_time'], marker='o', label=approach)

plt.xlabel('# threads')
plt.ylabel('Time')
plt.title('# threads vs Time')
plt.legend(title='Approach')
plt.show()

# %%
coalition_data = atp_time[atp_time['parameter'] == 'coalition_size']

plt.figure(figsize=(7, 4))

approaches = coalition_data['approach'].unique()

for approach in approaches:
    approach_data = coalition_data[coalition_data['approach'] == approach]
    plt.plot(approach_data['parameter_value'], approach_data['avg_time'], marker='o', label=approach)

plt.xlabel('Coalition Size')
plt.ylabel('Time')
plt.title('Coalition Size vs Time')
plt.legend(title='Approach')

plt.xticks(coalition_data['parameter_value'].unique().astype(int))

plt.show()

# %%
for approach in approaches:
    approach_data = coalition_data[coalition_data['approach'] == approach]
    plt.plot(approach_data['parameter_value'], approach_data['average_fidelity'], marker='o', label=approach)

plt.xlabel('Coalition Size')
plt.ylabel('Average Fidelity')
plt.title('Coalition Size vs Average Fidelity')
plt.legend(title='Approach')

plt.xticks(coalition_data['parameter_value'].unique().astype(int))

plt.show()

# %%
coalition_data = atp_time[(atp_time['parameter'] == 'coalition_size') & (atp_time['approach'] == 'rank')]

fidelity_data = {}

# fidelity values for each coalition size
for coalition_size in coalition_data['parameter_value'].unique():
    fidelity_values = coalition_data[coalition_data['parameter_value'] == coalition_size][['fidelity_0', 'fidelity_1', 'fidelity_2']]
    fidelity_data[coalition_size] = fidelity_values.values.flatten()

plt.figure(figsize=(7, 4))

plt.boxplot([fidelity_data[size] for size in sorted(fidelity_data.keys())], 
            positions=sorted(fidelity_data.keys()), widths=0.6)

plt.xlabel('Coalition Size')
plt.ylabel('Fidelity')
plt.title('Coalition Size vs Fidelity')
plt.xticks(ticks=sorted(fidelity_data.keys()), labels=sorted(fidelity_data.keys()))

plt.show()

# %%
coalition_data_rank = coalition_data[coalition_data['approach']=='rank']
for agreement in ['kendall', 'jaccard', 'euclidean']:
    plt.plot(coalition_data_rank['parameter_value'], coalition_data_rank[f'average_agreement_{agreement}'], marker='o', label=agreement)

plt.plot(coalition_data_rank['parameter_value'], 1-coalition_data_rank['average_fidelity']/86, marker='o', label='fidelity')

plt.xlabel('Coalition Size')
plt.ylabel('Average Agreement')
plt.title('Coalition Size vs Average Agreement')
plt.legend(title='Approach')

plt.xticks(coalition_data['parameter_value'].unique().astype(int))

plt.show()

# %%
samples_data = atp_time[atp_time['parameter'] == 'sample_size']

plt.figure(figsize=(8, 4))

approaches = samples_data['approach'].unique()

for approach in approaches:
    approach_data = samples_data[samples_data['approach'] == approach]
    plt.plot(approach_data['parameter_value'], approach_data['avg_time'], marker='o', label=approach)

plt.xlabel('Sample Size')
plt.ylabel('Time')
plt.title('Sample Size vs Time')
plt.legend(title='Approach')
plt.show()

# %%
for approach in approaches:
    approach_data = samples_data[samples_data['approach'] == approach]
    plt.plot(approach_data['parameter_value'], approach_data['average_fidelity'], marker='o', label=approach)

plt.xlabel('Sample Size')
plt.ylabel('Average Fidelity')
plt.title('Sample Size vs Average Fidelity')
plt.legend(title='Approach')
plt.show()

# %%
samples_data = atp_time[atp_time['parameter'] == 'sample_size']

fidelity_data = {}

for sample_size in samples_data['parameter_value'].unique():
    fidelity_values = samples_data[samples_data['parameter_value'] == sample_size][['fidelity_0', 'fidelity_1', 'fidelity_2']]
    fidelity_data[sample_size] = fidelity_values.values.flatten()

plt.figure(figsize=(7, 4))

plt.boxplot([fidelity_data[size] for size in sorted(fidelity_data.keys())], 
            positions=sorted(fidelity_data.keys()), widths=0.6)

plt.xlabel('Sample Size')
plt.ylabel('Fidelity')
plt.title('Sample Size vs Fidelity')
plt.xticks(ticks=sorted(fidelity_data.keys()), labels=sorted(fidelity_data.keys()))

plt.show()

# %%
samples_data_rank = samples_data[samples_data['approach']=='rank']
for agreement in ['kendall', 'jaccard', 'euclidean']:
    plt.plot(samples_data_rank['parameter_value'], samples_data_rank[f'average_agreement_{agreement}'], marker='o', label=agreement)

plt.plot(samples_data_rank['parameter_value'], 1-samples_data_rank['average_fidelity']/86, marker='o', label='fidelity')

plt.xlabel('Sample Size')
plt.ylabel('Average Agreement')
plt.title('Sample Size vs Average Agreement')
plt.legend(title='Approach')
plt.show()
