# %%
import sys

sys.path.append("..")

import numpy as np
import pandas as pd
from xai_ranking.benchmarks import (
    human_in_the_loop,
    hierarchical_ranking_explanation,
    lime_experiment,
    shap_experiment,
    sharp_experiment,
    participation_experiment,
)
from xai_ranking.datasets import (
    fetch_atp_data,
    fetch_csrank_data,
    fetch_higher_education_data,
    fetch_movers_data,
)
from xai_ranking.datasets.scorers import atp_score

RNG_SEED = 42

# %%
df = fetch_atp_data().head(20)
ranks = df.serve__standing_player
scores = df.serve__rating
X = df.drop(columns=["serve__standing_player", "serve__rating"])
df.head(5)
# Out:
#                    serve__standing_player  serve__rating  \
# player_name
# John Isner                              1          314.0
# Nick Kyrgios                            2          308.1
# Reilly Opelka                           3          307.1
# Hubert Hurkacz                          4          299.1
# Matteo Berrettini                       5          292.0
#
#                    serve__pct_1st_serve  serve__pct_1st_serve_points_won  \
# player_name
# John Isner                        0.684                            0.807
# Nick Kyrgios                      0.680                            0.788
# Reilly Opelka                     0.652                            0.795
# Hubert Hurkacz                    0.634                            0.782
# Matteo Berrettini                 0.640                            0.783
#
#                    serve__pct_2nd_serve_points_won  \
# player_name
# John Isner                                   0.535
# Nick Kyrgios                                 0.559
# Reilly Opelka                                0.578
# Hubert Hurkacz                               0.553
# Matteo Berrettini                            0.516
#
#                    serve__pct_service_games_won  serve__avg_aces_match  \
# player_name
# John Isner                                0.917                   22.4
# Nick Kyrgios                              0.929                   15.9
# Reilly Opelka                             0.908                   15.9
# Hubert Hurkacz                            0.905                   13.3
# Matteo Berrettini                         0.878                   12.4
#
#                    serve__avg_double_faultsmatch
# player_name
# John Isner                                   2.7
# Nick Kyrgios                                 3.4
# Reilly Opelka                                2.1
# Hubert Hurkacz                               1.6
# Matteo Berrettini                            2.1

# %%
(X.values[0] * np.array([100, 100, 100, 100, 1, -1])).sum() == scores.values[0]
# Out:
# True

# %%
atp_score(X)
# Out:
# player_name
# John Isner               314.0
# Nick Kyrgios             308.1
# Reilly Opelka            307.1
# Hubert Hurkacz           299.1
# Matteo Berrettini        292.0
# Nicolas Jarry            291.8
# Novak Djokovic           290.7
# Maxime Cressy            289.3
# Ben Shelton              286.6
# Stefanos Tsitsipas       286.6
# Felix Auger-Aliassime    286.1
# Casper Ruud              284.1
# Daniil Medvedev          283.1
# Taylor Fritz             283.1
# Brandon Nakashima        283.0
# Marin Cilic              282.5
# Arthur Rinderknech       281.2
# Thiago Monteiro          281.0
# Alexander Zverev         280.5
# Andrey Rublev            280.1
# dtype: float64

# %%
sharp_results = sharp_experiment(X, atp_score, random_state=RNG_SEED)
pd.DataFrame(sharp_results, columns=X.columns, index=X.index)
# Out:
#                        serve__pct_1st_serve  serve__pct_1st_serve_points_won  \
# player_name
# John Isner                         1.650000                         1.645000
# Nick Kyrgios                       1.569167                         1.008333
# Reilly Opelka                      0.385000                         1.115000
# Hubert Hurkacz                    -0.265000                         0.835000
# Matteo Berrettini                  0.135833                         1.360833
# Nicolas Jarry                      0.450833                         3.397500
# Novak Djokovic                     1.285000                         0.367500
# Maxime Cressy                     -1.699167                         1.095833
# Ben Shelton                       -4.347500                         1.957500
# Stefanos Tsitsipas                -0.506667                        -0.103333
# Felix Auger-Aliassime              0.754167                         0.263333
# Casper Ruud                        1.497500                        -1.816667
# Daniil Medvedev                    0.227500                        -0.169167
# Taylor Fritz                      -1.829167                        -0.512500
# Brandon Nakashima                  0.380000                        -2.111667
# Marin Cilic                       -5.055000                         1.347500
# Arthur Rinderknech                 1.728333                        -2.119167
# Thiago Monteiro                    1.830833                        -4.494167
# Alexander Zverev                   4.585000                        -2.390000
# Andrey Rublev                     -2.776667                        -0.676667
#
#                        serve__pct_2nd_serve_points_won  \
# player_name
# John Isner                                    0.304167
# Nick Kyrgios                                  1.411667
# Reilly Opelka                                 1.928333
# Hubert Hurkacz                                1.428333
# Matteo Berrettini                            -0.349167
# Nicolas Jarry                                -2.364167
# Novak Djokovic                                2.821667
# Maxime Cressy                                 1.420833
# Ben Shelton                                   1.489167
# Stefanos Tsitsipas                            2.787500
# Felix Auger-Aliassime                        -2.121667
# Casper Ruud                                   2.509167
# Daniil Medvedev                              -1.469167
# Taylor Fritz                                  0.268333
# Brandon Nakashima                             0.615833
# Marin Cilic                                  -1.277500
# Arthur Rinderknech                           -4.225000
# Thiago Monteiro                               1.495000
# Alexander Zverev                             -4.705833
# Andrey Rublev                                -1.967500
#
#                        serve__pct_service_games_won  serve__avg_aces_match  \
# player_name
# John Isner                                 2.098333               3.773333
# Nick Kyrgios                               2.526667               2.261667
# Reilly Opelka                              1.682500               2.087500
# Hubert Hurkacz                             2.125833               1.715000
# Matteo Berrettini                          1.553333               2.175000
# Nicolas Jarry                              0.700833               1.997500
# Novak Djokovic                             1.141667              -2.947500
# Maxime Cressy                              1.880833               3.690000
# Ben Shelton                                2.870833               0.122500
# Stefanos Tsitsipas                         0.263333              -1.819167
# Felix Auger-Aliassime                      0.070833               1.151667
# Casper Ruud                               -0.859167              -3.687500
# Daniil Medvedev                            0.398333              -0.441667
# Taylor Fritz                              -2.096667               0.843333
# Brandon Nakashima                         -2.069167              -2.653333
# Marin Cilic                               -1.013333               1.194167
# Arthur Rinderknech                        -2.531667              -0.560833
# Thiago Monteiro                           -4.215000              -3.538333
# Alexander Zverev                          -2.458333              -2.675833
# Andrey Rublev                             -2.070000              -2.687500
#
#                        serve__avg_double_faultsmatch
# player_name
# John Isner                                 -0.020833
# Nick Kyrgios                               -0.327500
# Reilly Opelka                               0.251667
# Hubert Hurkacz                              0.610833
# Matteo Berrettini                           0.574167
# Nicolas Jarry                               0.267500
# Novak Djokovic                              0.781667
# Maxime Cressy                              -3.938333
# Ben Shelton                                -1.642500
# Stefanos Tsitsipas                          0.828333
# Felix Auger-Aliassime                      -0.668333
# Casper Ruud                                 0.806667
# Daniil Medvedev                            -1.095833
# Taylor Fritz                                0.776667
# Brandon Nakashima                           1.288333
# Marin Cilic                                -0.745833
# Arthur Rinderknech                          1.158333
# Thiago Monteiro                             1.371667
# Alexander Zverev                           -0.905000
# Andrey Rublev                               0.628333

# %%
shap_results = shap_experiment(X, atp_score)
pd.DataFrame(shap_results, columns=X.columns, index=X.index)
# Out:
#                        serve__pct_1st_serve  serve__pct_1st_serve_points_won  \
# player_name
# John Isner                             4.13                            3.485
# Nick Kyrgios                           3.73                            1.585
# Reilly Opelka                          0.93                            2.285
# Hubert Hurkacz                        -0.87                            0.985
# Matteo Berrettini                     -0.27                            1.085
# Nicolas Jarry                          0.23                            3.985
# Novak Djokovic                         1.33                           -0.015
# Maxime Cressy                         -2.67                            1.085
# Ben Shelton                           -5.67                            1.785
# Stefanos Tsitsipas                    -1.17                           -0.715
# Felix Auger-Aliassime                  0.43                           -0.115
# Casper Ruud                            1.03                           -2.415
# Daniil Medvedev                       -0.27                           -0.715
# Taylor Fritz                          -2.37                           -1.015
# Brandon Nakashima                      0.23                           -2.315
# Marin Cilic                           -5.47                            1.185
# Arthur Rinderknech                     1.43                           -2.315
# Thiago Monteiro                        1.93                           -4.515
# Alexander Zverev                       5.93                           -2.615
# Andrey Rublev                         -2.57                           -0.715
#
#                        serve__pct_2nd_serve_points_won  \
# player_name
# John Isner                                        0.53
# Nick Kyrgios                                      2.93
# Reilly Opelka                                     4.83
# Hubert Hurkacz                                    2.33
# Matteo Berrettini                                -1.37
# Nicolas Jarry                                    -3.97
# Novak Djokovic                                    3.23
# Maxime Cressy                                     1.43
# Ben Shelton                                       1.33
# Stefanos Tsitsipas                                2.23
# Felix Auger-Aliassime                            -2.57
# Casper Ruud                                       1.93
# Daniil Medvedev                                  -1.97
# Taylor Fritz                                     -0.37
# Brandon Nakashima                                 0.43
# Marin Cilic                                      -1.47
# Arthur Rinderknech                               -4.27
# Thiago Monteiro                                   1.53
# Alexander Zverev                                 -5.07
# Andrey Rublev                                    -1.67
#
#                        serve__pct_service_games_won  serve__avg_aces_match  \
# player_name
# John Isner                                     4.66                 11.545
# Nick Kyrgios                                   5.86                  5.045
# Reilly Opelka                                  3.76                  5.045
# Hubert Hurkacz                                 3.46                  2.445
# Matteo Berrettini                              0.76                  1.545
# Nicolas Jarry                                 -0.04                  1.545
# Novak Djokovic                                 0.66                 -4.955
# Maxime Cressy                                  1.76                  3.645
# Ben Shelton                                    2.46                 -0.855
# Stefanos Tsitsipas                            -0.74                 -3.255
# Felix Auger-Aliassime                         -0.74                  0.145
# Casper Ruud                                   -1.74                 -4.955
# Daniil Medvedev                               -0.64                 -1.655
# Taylor Fritz                                  -2.84                 -0.455
# Brandon Nakashima                             -2.64                 -3.455
# Marin Cilic                                   -1.34                  0.645
# Arthur Rinderknech                            -2.94                 -1.255
# Thiago Monteiro                               -4.54                 -4.355
# Alexander Zverev                              -2.94                 -3.455
# Andrey Rublev                                 -2.24                 -2.955
#
#                        serve__avg_double_faultsmatch
# player_name
# John Isner                                      0.15
# Nick Kyrgios                                   -0.55
# Reilly Opelka                                   0.75
# Hubert Hurkacz                                  1.25
# Matteo Berrettini                               0.75
# Nicolas Jarry                                   0.55
# Novak Djokovic                                  0.95
# Maxime Cressy                                  -5.45
# Ben Shelton                                    -1.95
# Stefanos Tsitsipas                              0.75
# Felix Auger-Aliassime                          -0.55
# Casper Ruud                                     0.75
# Daniil Medvedev                                -1.15
# Taylor Fritz                                    0.65
# Brandon Nakashima                               1.25
# Marin Cilic                                    -0.55
# Arthur Rinderknech                              1.05
# Thiago Monteiro                                 1.45
# Alexander Zverev                               -0.85
# Andrey Rublev                                   0.75

# %%
hre_results = hierarchical_ranking_explanation(X, atp_score, model_type="OLS", s=int(X.shape[0]**0.25))
hre_results
# Out:
#                        serve__pct_1st_serve  serve__pct_1st_serve_points_won  \
# player_name
# John Isner                        75.412016                       103.572058
# Nick Kyrgios                      73.417122                       102.969840
# Reilly Opelka                     76.793557                       112.482442
# Hubert Hurkacz                   109.613007                        94.412972
# Matteo Berrettini                 79.284704                       102.607108
# Nicolas Jarry                     90.987170                        95.033613
# Novak Djokovic                    86.628023                        97.985727
# Maxime Cressy                    100.902848                        89.252386
# Ben Shelton                       99.707071                        92.041871
# Stefanos Tsitsipas                99.890610                        92.152434
# Felix Auger-Aliassime             96.792630                        91.534804
# Casper Ruud                       94.897718                       110.301335
# Daniil Medvedev                   96.526240                        90.944260
# Taylor Fritz                      97.540200                        91.094014
# Brandon Nakashima                 97.561101                        91.194675
# Marin Cilic                       98.917714                        92.014451
# Arthur Rinderknech                99.044519                        91.759157
# Thiago Monteiro                   98.252470                        91.800250
# Alexander Zverev                  98.943768                        93.430084
# Andrey Rublev                    126.385771                        73.540211
#
#                        serve__pct_2nd_serve_points_won  \
# player_name
# John Isner                                   93.253192
# Nick Kyrgios                                100.601348
# Reilly Opelka                                97.781151
# Hubert Hurkacz                               92.015407
# Matteo Berrettini                           102.281254
# Nicolas Jarry                                86.708423
# Novak Djokovic                               89.230108
# Maxime Cressy                                96.598468
# Ben Shelton                                 100.163788
# Stefanos Tsitsipas                           99.928127
# Felix Auger-Aliassime                        90.588006
# Casper Ruud                                  87.640254
# Daniil Medvedev                              99.583099
# Taylor Fritz                                100.044115
# Brandon Nakashima                           100.130584
# Marin Cilic                                 100.722336
# Arthur Rinderknech                          100.337245
# Thiago Monteiro                              99.571057
# Alexander Zverev                             95.589879
# Andrey Rublev                                87.350611
#
#                        serve__pct_service_games_won  serve__avg_aces_match  \
# player_name
# John Isner                               117.922965               1.030172
# Nick Kyrgios                             113.917840               1.075709
# Reilly Opelka                            105.634787               1.027775
# Hubert Hurkacz                           102.036759               1.110180
# Matteo Berrettini                        110.346985               0.932986
# Nicolas Jarry                            120.318177               0.888099
# Novak Djokovic                           119.403573               0.891216
# Maxime Cressy                            110.799800               1.045640
# Ben Shelton                              106.966666               1.034521
# Stefanos Tsitsipas                       106.931688               1.026913
# Felix Auger-Aliassime                    116.616527               0.962010
# Casper Ruud                              104.138929               0.880737
# Daniil Medvedev                          110.830080               1.027648
# Taylor Fritz                             109.554262               1.033820
# Brandon Nakashima                        109.395116               1.033299
# Marin Cilic                              107.175727               1.030442
# Arthur Rinderknech                       107.593249               1.019694
# Thiago Monteiro                          108.882717               0.998316
# Alexander Zverev                         110.331308               0.921345
# Andrey Rublev                             96.975545               3.011554
#
#                        serve__avg_double_faultsmatch
# player_name
# John Isner                                 -0.839311
# Nick Kyrgios                               -0.627492
# Reilly Opelka                              -0.556409
# Hubert Hurkacz                             -1.386733
# Matteo Berrettini                          -0.149706
# Nicolas Jarry                              -0.969731
# Novak Djokovic                             -0.997574
# Maxime Cressy                              -1.065343
# Ben Shelton                                -1.043903
# Stefanos Tsitsipas                         -1.035476
# Felix Auger-Aliassime                      -1.169616
# Casper Ruud                                -1.197602
# Daniil Medvedev                            -1.062021
# Taylor Fritz                               -1.050294
# Brandon Nakashima                          -1.048340
# Marin Cilic                                -0.992537
# Arthur Rinderknech                         -0.966158
# Thiago Monteiro                            -0.975314
# Alexander Zverev                           -1.095001
# Andrey Rublev                              -2.369375

# %%
hilw = human_in_the_loop(X, atp_score)
hilw
# Out:
# Index(['serve__pct_1st_serve', 'serve__pct_1st_serve_points_won',
#        'serve__pct_2nd_serve_points_won', 'serve__pct_service_games_won',
#        'serve__avg_aces_match', 'serve__avg_double_faultsmatch'],
#       dtype='object')
#     serve__pct_1st_serve_contri  serve__pct_1st_serve_points_won_contri  \
# 0                        0.0413                                 0.03485
# 1                        0.0373                                 0.01585
# 2                        0.0093                                 0.02285
# 3                        0.0087                                 0.00985
# 4                        0.0027                                 0.01085
# 5                        0.0023                                 0.03985
# 6                        0.0133                                 0.00015
# 7                        0.0267                                 0.01085
# 8                        0.0567                                 0.01785
# 9                        0.0117                                 0.00715
# 10                       0.0043                                 0.00115
# 11                       0.0103                                 0.02415
# 12                       0.0027                                 0.00715
# 13                       0.0237                                 0.01015
# 14                       0.0023                                 0.02315
# 15                       0.0547                                 0.01185
# 16                       0.0143                                 0.02315
# 17                       0.0193                                 0.04515
# 18                       0.0593                                 0.02615
# 19                       0.0257                                 0.00715
#
#     serve__pct_2nd_serve_points_won_contri  \
# 0                                   0.0053
# 1                                   0.0293
# 2                                   0.0483
# 3                                   0.0233
# 4                                   0.0137
# 5                                   0.0397
# 6                                   0.0323
# 7                                   0.0143
# 8                                   0.0133
# 9                                   0.0223
# 10                                  0.0257
# 11                                  0.0193
# 12                                  0.0197
# 13                                  0.0037
# 14                                  0.0043
# 15                                  0.0147
# 16                                  0.0427
# 17                                  0.0153
# 18                                  0.0507
# 19                                  0.0167
#
#     serve__pct_service_games_won_contri  serve__avg_aces_match_contri  \
# 0                                0.0466                        11.545
# 1                                0.0586                         5.045
# 2                                0.0376                         5.045
# 3                                0.0346                         2.445
# 4                                0.0076                         1.545
# 5                                0.0004                         1.545
# 6                                0.0066                         4.955
# 7                                0.0176                         3.645
# 8                                0.0246                         0.855
# 9                                0.0074                         3.255
# 10                               0.0074                         0.145
# 11                               0.0174                         4.955
# 12                               0.0064                         1.655
# 13                               0.0284                         0.455
# 14                               0.0264                         3.455
# 15                               0.0134                         0.645
# 16                               0.0294                         1.255
# 17                               0.0454                         4.355
# 18                               0.0294                         3.455
# 19                               0.0224                         2.955
#
#     serve__avg_double_faultsmatch_contri
# 0                                   0.15
# 1                                   0.55
# 2                                   0.75
# 3                                   1.25
# 4                                   0.75
# 5                                   0.55
# 6                                   0.95
# 7                                   5.45
# 8                                   1.95
# 9                                   0.75
# 10                                  0.55
# 11                                  0.75
# 12                                  1.15
# 13                                  0.65
# 14                                  1.25
# 15                                  0.55
# 16                                  1.05
# 17                                  1.45
# 18                                  0.85
# 19                                  0.75

# %%
part_results = participation_experiment(X, atp_score, top_k=5)
part_results
# Out:
# serve__pct_1st_serve               0.031744
# serve__pct_1st_serve_points_won    0.038275
# serve__pct_2nd_serve_points_won    0.026543
# serve__pct_service_games_won       0.043887
# serve__avg_aces_match              0.747419
# serve__avg_double_faultsmatch      0.112131
# dtype: float64

# %% [markdown]
# # Test using DuckDB
#
# Ignore this section. This is just a test to see if DuckDB is worth exploring in the future. Based on some talks I saw at SIGMOD.

# %%
X.reset_index(inplace=True)
scores = scores.to_frame()
scores.reset_index(inplace=True)

# %%
import duckdb as db

weights = {k: v for k, v in zip(X.columns.drop("player_name"), [100, 100, 100, 100, 1, -1])}
rename_cols = ", ".join([f"{col} as {col.replace("serve__", "")}" for col in X.columns.drop("player_name")])
db.sql(
f"""
SELECT 
    X.player_name,
    {rename_cols},
    {"+".join(f"{k}*{v}" for k, v in weights.items())} as score,
    ROW_NUMBER() OVER (ORDER BY score DESC) as rank
FROM X 
ORDER BY score DESC
"""
).df()
# Out:
#               player_name  pct_1st_serve  pct_1st_serve_points_won  \
# 0              John Isner          0.684                     0.807
# 1            Nick Kyrgios          0.680                     0.788
# 2           Reilly Opelka          0.652                     0.795
# 3          Hubert Hurkacz          0.634                     0.782
# 4       Matteo Berrettini          0.640                     0.783
# 5           Nicolas Jarry          0.645                     0.812
# 6          Novak Djokovic          0.656                     0.772
# 7           Maxime Cressy          0.616                     0.783
# 8      Stefanos Tsitsipas          0.631                     0.765
# 9             Ben Shelton          0.586                     0.790
# 10  Felix Auger-Aliassime          0.647                     0.771
# 11            Casper Ruud          0.653                     0.748
# 12        Daniil Medvedev          0.640                     0.765
# 13           Taylor Fritz          0.619                     0.762
# 14      Brandon Nakashima          0.645                     0.749
# 15            Marin Cilic          0.588                     0.784
# 16     Arthur Rinderknech          0.657                     0.749
# 17        Thiago Monteiro          0.662                     0.727
# 18       Alexander Zverev          0.702                     0.746
# 19          Andrey Rublev          0.617                     0.765
#
#     pct_2nd_serve_points_won  pct_service_games_won  avg_aces_match  \
# 0                      0.535                  0.917            22.4
# 1                      0.559                  0.929            15.9
# 2                      0.578                  0.908            15.9
# 3                      0.553                  0.905            13.3
# 4                      0.516                  0.878            12.4
# 5                      0.490                  0.870            12.4
# 6                      0.562                  0.877             5.9
# 7                      0.544                  0.888            14.5
# 8                      0.552                  0.863             7.6
# 9                      0.543                  0.895            10.0
# 10                     0.504                  0.863            11.0
# 11                     0.549                  0.853             5.9
# 12                     0.510                  0.864             9.2
# 13                     0.526                  0.842            10.4
# 14                     0.534                  0.844             7.4
# 15                     0.515                  0.857            11.5
# 16                     0.487                  0.841             9.6
# 17                     0.545                  0.825             6.5
# 18                     0.479                  0.841             7.4
# 19                     0.513                  0.848             7.9
#
#     avg_double_faultsmatch  score  rank
# 0                      2.7  314.0     1
# 1                      3.4  308.1     2
# 2                      2.1  307.1     3
# 3                      1.6  299.1     4
# 4                      2.1  292.0     5
# 5                      2.3  291.8     6
# 6                      1.9  290.7     7
# 7                      8.3  289.3     8
# 8                      2.1  286.6     9
# 9                      4.8  286.6    10
# 10                     3.4  286.1    11
# 11                     2.1  284.1    12
# 12                     4.0  283.1    13
# 13                     2.2  283.1    14
# 14                     1.6  283.0    15
# 15                     3.4  282.5    16
# 16                     1.8  281.2    17
# 17                     1.4  281.0    18
# 18                     3.7  280.5    19
# 19                     2.1  280.1    20

# %%
def test_ddb():
    rename_cols = ", ".join([f"{col} as {col.replace("serve__", "")}" for col in X.columns])
    return db.sql(
    f"""
    SELECT 
        {rename_cols},
        {"+".join(f"{k}*{v}" for k, v in weights.items())} as score,
        ROW_NUMBER() OVER (ORDER BY score DESC) as rank
    FROM X 
    ORDER BY score DESC
    """
    )

# %%
from sharp.utils import scores_to_ordering

def test_pd():
    X_ = X.copy()
    X_.rename(columns={col: col.replace("serve__", "") for col in X_.columns}, inplace=True)
    X_["score"] = atp_score(X_.drop(columns=["player_name"]))
    X_.sort_values("score", ascending=False, inplace=True)
    X_["rank"] = scores_to_ordering(X_["score"])
    return X_

# %%
# %timeit test_ddb()
# %timeit test_pd()
# Out:
# 2.63 ms ± 509 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.02 ms ± 251 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
