# %%
import os
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from sharp import ShaRP

sys.path.append("..")

from itertools import product
from lightgbm import LGBMRanker
from sklearn.utils import check_random_state
from xai_ranking.benchmarks import (
    human_in_the_loop_experiment,
    human_in_the_loop_batch_experiment,
    hierarchical_ranking_explanation,
    hierarchical_ranking_batch_explanation,
    lime_experiment,
    lime_batch_experiment,
    shap_experiment,
    shap_batch_experiment,
    sharp_experiment,
    sharp_batch_experiment,
    # participation_experiment,
)
from xai_ranking.preprocessing import (
    preprocess_atp_data,
    preprocess_csrank_data,
    preprocess_higher_education_data,
    preprocess_movers_data,
    preprocess_synthetic_data,
)
from xai_ranking.datasets import (
    fetch_atp_data,
    fetch_csrank_data,
    fetch_higher_education_data,
    fetch_movers_data,
    fetch_synthetic_data,
)
from xai_ranking.scorers import (
    atp_score,
    csrank_score,
    higher_education_score,
    synthetic_equal_score_3ftrs,
)
from xai_ranking.metrics._base import row_wise_kendall
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from mlresearch.utils import check_random_states, set_matplotlib_style
from xai_ranking.utils import scores_to_ordering

RNG_SEED = 42

# %%
datasets = [
    {
        "name": "ATP",
        "data": preprocess_atp_data(fetch_atp_data()),
        "scorer": atp_score,
    },
    {
        "name": "CSRank",
        "data": preprocess_csrank_data(fetch_csrank_data()),
        "scorer": csrank_score,
    },
    {
        "name": "Higher Education",
        "data": preprocess_higher_education_data(
            fetch_higher_education_data(year=2020)
        ),
        "scorer": higher_education_score,
    },
    # {
    #     "name": "Moving Company",
    #     "data": preprocess_movers_data(fetch_movers_data(test=True)),
    #     "scorer": model.predict,
    # },
    {
        "name": "Synthetic_0",
        "data": preprocess_synthetic_data(
            fetch_synthetic_data(synth_dt_version=0, item_num=2000)
        ),
        "scorer": synthetic_equal_score_3ftrs,
    },
    {
        "name": "Synthetic_1",
        "data": preprocess_synthetic_data(
            fetch_synthetic_data(synth_dt_version=1, item_num=2000)
        ),
        "scorer": synthetic_equal_score_3ftrs,
    },
    {
        "name": "Synthetic_2",
        "data": preprocess_synthetic_data(
            fetch_synthetic_data(synth_dt_version=2, item_num=2000)
        ),
        "scorer": synthetic_equal_score_3ftrs,
    },
]
xai_methods = [
    {
        "iterations": 1,
        "name": "ShaRP_RANK",
        "experiment": sharp_experiment,
        "kwargs": {
            "qoi": "rank",
            "verbose": True,
            "sample_size": None,
            "measure": "shapley",
            "n_jobs": -1,
            "replace": False,
        },
    },
    {
        "iterations": 1,
        "name": "ShaRP_SCORE",
        "experiment": sharp_experiment,
        "kwargs": {
            "qoi": "rank_score",
            "verbose": True,
            "sample_size": None,
            "measure": "shapley",
            "n_jobs": -1,
            "replace": False,
        },
    },
]

# %%
def read_results_from_files():
    return_dict = {}
    for cur_dataset in datasets:
        return_dict[cur_dataset["name"]] = {}
        for cur_xai_method in xai_methods:
            return_dict[cur_dataset["name"]][cur_xai_method["name"]] = []
            for iteration in range(cur_xai_method["iterations"]):
                fname = (
                    f"results/contributions/_contributions_"
                    f"{cur_dataset['name']}_{cur_xai_method['name']}_"
                    f"{iteration}.csv"
                )
                if os.path.isfile(fname):
                    (
                        return_dict[cur_dataset["name"]][cur_xai_method["name"]].append(
                            pd.read_csv(fname, index_col=0)
                        )
                    )
    return return_dict

# %%
results = read_results_from_files()

# %%
# results

# %%
methods = [method for method in results["ATP"].keys() if not method.startswith("BATCH")]

for dataset in datasets:
    print(dataset["name"])
    df_rank = results[dataset["name"]]["ShaRP_RANK"][0]
    df_score = results[dataset["name"]]["ShaRP_SCORE"][0]
    scores = dataset["scorer"](dataset["data"][0])
    rank = scores_to_ordering(dataset["scorer"](dataset["data"][0]))
    # print(type(rank))
    xai = ShaRP(
        qoi="rank",
        target_function=dataset["scorer"],
        measure="shapley",
        sample_size=None,
        replace=False,
        random_state=42,
    )
    xai.fit(dataset["data"][0])
    xai_score = ShaRP(
        qoi="rank_score",
        target_function=dataset["scorer"],
        measure="shapley",
        sample_size=None,
        replace=False,
        random_state=42,
    )
    xai_score.fit(dataset["data"][0])
    mismatch = 0
    for index, row in df_rank.iterrows():
        kendall = row_wise_kendall(row.to_numpy(), df_score.loc[[index]].to_numpy()[0])
        if kendall != 1.0:
            print(index, " ", kendall)
            mismatch += 1
        if kendall < 0.7:

            # WATERFALL RANK
            print(rank.mean())
            xai.plot.waterfall(
                row.to_numpy(),
                feature_values=dataset["data"][0].loc[[index]].to_numpy()[0],
                mean_target_value=rank.mean(),
            )
            plt.savefig(
                f"results/QoI/waterfall-{dataset["name"]}-rank-{index}.pdf",
                format="pdf",
                bbox_inches="tight",
                transparent=True,
            )
            plt.close()

            # WATERFALL SCORE
            xai_score.plot.waterfall(
                df_score.loc[[index]].to_numpy()[0],
                feature_values=dataset["data"][0].loc[[index]].to_numpy()[0],
                mean_target_value=scores.mean(),
            )
            plt.savefig(
                f"results/QoI/waterfall-{dataset["name"]}-score-{index}.pdf",
                format="pdf",
                bbox_inches="tight",
                transparent=True,
            )
            plt.close()

    print("\n")
    print(
        "Mismatch:",
        mismatch,
        "/",
        results[dataset["name"]]["ShaRP_RANK"][0].shape[0],
        " (",
        float(mismatch) / results[dataset["name"]]["ShaRP_RANK"][0].shape[0] * 100,
        ")",
    )

    print("\n\n")
# Out:
# ATP
# Nick Kyrgios   0.9333333333333333
# Casper Ruud   0.9333333333333333
# Taylor Fritz   0.9333333333333333
# Brandon Nakashima   0.8666666666666667
# Arthur Rinderknech   0.9333333333333333
# Thiago Monteiro   0.8
# Pablo Carreno Busta   0.9333333333333333
# Rafael Nadal   0.9333333333333333
# Borna Coric   0.9333333333333333
# Roberto Bautista Agut   0.9333333333333333
# Grigor Dimitrov   0.8666666666666667
# Holger Rune   0.9333333333333333
# Frances Tiafoe   0.8666666666666667
# Tallon Griekspoor   0.8
# Miomir Kecmanovic   0.9333333333333333
# Alexander Bublik   0.8666666666666667
# Sebastian Korda   0.8
# Andy Murray   0.9333333333333333
# Daniel Evans   0.9333333333333333
# Tommy Paul   0.8666666666666667
# Dominic Thiem   0.9333333333333333
# Mackenzie McDonald   0.9333333333333333
# Ilya Ivashka   0.9333333333333333
# Filip Krajinovic   0.9333333333333333
# Babol Noshirvani University of Technology   0.9
# Birkbeck   0.9
# University of Bremen   0.9
# Brunel University London   0.9
# University of California   0.6
# 699.0
# Clark University   0.9
# University of Crete   0.9
# University of Denver   0.9
# Goldsmiths   0.9
# Hanyang University   0.9
# Hasselt University   0.9
# IMT Atlantique   0.6
# 699.0
# Iowa State University   0.9
# Loughborough University   0.8
# University of Manitoba   0.9
# Nankai University   0.9
# University of Occupational and Environmental Health   0.9
# Örebro University   0.9
# University of Perugia   0.7
# University of Pisa   0.9
# RMIT University   0.9
# University of Salerno   0.8
# University of Turku   0.9
# TU Wien   0.9
# Université de Versailles Saint-Quentin-en-Yvelines   0.9
# Aberystwyth University   0.9
# University of Alabama   0.7
# American University   0.9
# Bangor University   0.9
# University of Bordeaux   0.8
# Bournemouth University   0.9
# Cankaya University   0.9
# Centrale Nantes   0.7
# Charles University in Prague   0.9
# City   0.8
# Covenant University   0.9
# University of Desarrollo   0.9
# Drexel University   0.9
# Edith Cowan University   0.9
# Federal University of Toulouse Midi-Pyrénées   0.9
# University of Ferrara   0.9
# University of Genoa   0.7
# Georgia State University   0.9
# Harbin Institute of Technology   0.9
# Hong Kong Baptist University   0.8
# University of Houston   0.9
# Hunan University   0.9
# Indian Institute of Technology Delhi   0.9
# Indian Institute of Technology Kharagpur   0.9
# University of Innsbruck   0.8
# ITMO University   0.5
# 699.0
# University of Kansas   0.9
# University of Kentucky   0.9
# University of KwaZulu-Natal   0.9
# Kyushu University   0.9
# Leibniz University Hannover   0.7
# Linköping University   0.9
# Mansoura University   0.9
# University of Milan-Bicocca   0.8
# University of Modena and Reggio Emilia   0.9
# National Research Nuclear University MEPhI   0.9
# University of Nebraska-Lincoln   0.9
# Norwegian University of Science and Technology   0.9
# Oklahoma State University   0.8
# University of Peradeniya   0.9
# University of the Philippines   0.9
# Polytechnic University of Bari   0.9
# University of Porto   0.9
# Rensselaer Polytechnic Institute   0.9
# Royal Veterinary College   0.9
# Sabancı University   0.7
# University of St Gallen   0.9
# University of Saskatchewan   0.9
# Sejong University   0.7
# Semmelweis University   0.9
# University of Siena   0.7
# University of South Carolina-Columbia   0.9
# University of Strasbourg   0.9
# University of Strathclyde   0.9
# The University of Texas at San Antonio   0.8
# Tokyo Medical and Dental University (TMDU)   0.9
# University of Trieste   0.8
# University of Tsukuba   0.9
# University of Turin   0.9
# University of Valencia   0.9
# Verona University   0.9
# Yasouj University   0.9
# York University   0.9
# University of Alabama in Huntsville   0.9
# University of L’Aquila   0.9
# Bar-Ilan University   0.9
# Binghamton University   0.7
# University of Brescia   0.9
# Carleton University   0.9
# University of Catania   0.9
# Catholic University of the Sacred Heart   0.7
# CentraleSupélec   0.7
# Institute of Chemical Technology   0.7
# Claude Bernard University Lyon 1   0.8
# Complutense University of Madrid   0.8
# East China Normal University   0.7
# Florida International University   0.9
# University of Graz   0.9
# Graz University of Technology   0.8
# University of Greifswald   0.8
# University of Guelph   0.7
# University of Haifa   0.9
# Hamburg University of Technology   0.8
# University of Hull   0.9
# University of Idaho   0.9
# Indian Institute of Technology Roorkee   0.9
# University of Jyväskylä   0.8
# University of Kashan   0.9
# Keele University   0.9
# King Saud University   0.7
# Koç University   0.8
# Lappeenranta-Lahti University of Technology LUT   0.9
# University of Limerick   0.9
# Lincoln University   0.8
# University of Lisbon   0.9
# Marche Polytechnic University   0.9
# University of Nebraska Medical Center   0.9
# North-West University   0.9
# Norwegian University of Life Sciences   0.9
# Polytechnic University of Turin   0.8
# Pontifical Catholic University of Chile   0.8
# Renmin University of China   0.7
# University of Rhode Island   0.9
# University of Rome III   0.9
# University of Rovira i Virgili   0.9
# San Diego State University   0.9
# Sharif University of Technology   0.9
# Shenzhen University   0.9
# University of Siegen   0.9
# Soochow University   0.8
# South China University of Technology   0.9
# Southeast University   0.9
# Tehran University of Medical Sciences   0.8
# University of Udine   0.8
# Victoria University of Wellington   0.9
# University of Wisconsin-Milwaukee   0.9
# Xiamen University   0.7
# Xi’an Jiaotong University   0.9
# Yokohama City University   0.9
# Amedeo Avogadro University of Eastern Piedmont   0.9
# Amrita Vishwa Vidyapeetham   0.8
# University of the Andes   0.9
# University of Arkansas   0.8
# Auburn University   0.7
# Banaras Hindu University   0.8
# University of the Basque Country   0.7
# Beijing Institute of Technology   0.9
# University of Beira Interior   0.9
# University of Bergamo   0.8
# Boğaziçi University   0.9
# University of Brighton   0.9
# University of Central Florida   0.9
# Central Queensland University   0.9
# Chemnitz University of Technology   0.9
# China Agricultural University   0.9
# China University of Petroleum   0.8
# Clemson University   0.5
# 699.0
# University of Coimbra   0.8
# Concordia University   0.9
# Coventry University   0.8
# Creighton University   0.9
# Dalian University of Technology   0.8
# University of Electronic Science and Technology of China   0.9
# Eötvös Loránd University   0.9
# Ewha Womans University   0.9
# Federal University of Minas Gerais   0.9
# Federal University of Rio Grande do Sul   0.8
# Federal University of São Paulo (UNIFESP)   0.7
# Ferhat Abbas Sétif University 1   0.9
# University of Granada   0.9
# University of Hertfordshire   0.9
# Hiroshima University   0.9
# Huazhong Agricultural University   0.9
# University of Huddersfield   0.9
# Indian Institute of Technology Bhubaneswar   0.9
# Indian Institute of Technology Guwahati   0.8
# University of International Business and Economics   0.9
# University of Ioannina   0.9
# Isfahan University of Technology   0.9
# Istanbul Technical University   0.9
# Jagiellonian University   0.8
# Jamia Millia Islamia   0.9
# Jaume I University   0.9
# Johannes Kepler University of Linz   0.7
# University of Kaiserslautern   0.7
# Kansas State University   0.7
# Kazan Federal University   0.8
# Kent State University   0.8
# King Khalid University   0.9
# Kobe University   0.9
# Kurume University   0.9
# Lakehead University   0.8
# Lehigh University   0.7
# University of Leoben   0.9
# University of Ljubljana   0.7
# Mahidol University   0.9
# Universiti Malaysia Perlis   0.9
# University of Malta   0.9
# University of Maryland   0.5
# 699.0
# Masaryk University   0.9
# Metropolitan Autonomous University   0.9
# Middle East Technical University   0.8
# Miguel Hernández University of Elche   0.9
# University of Minho   0.9
# Monterrey Institute of Technology   0.9
# University of Nantes   0.9
# National Institute of Applied Sciences of Lyon (INSA Lyon)   0.8
# National Technical University of Athens   0.9
# University of Nevada   0.8
# Nippon Medical School   0.9
# University of North Carolina at Greensboro   0.9
# Northwestern Polytechnical University   0.9
# Nottingham Trent University   0.9
# NOVA University of Lisbon   0.8
# Ohio University (Main campus)   0.8
# Old Dominion University   0.8
# Oxford Brookes University   0.9
# Palacký University Olomouc   0.9
# University of Palermo   0.9
# Panjab University   0.8
# Pontifical Catholic University of Rio de Janeiro (PUC-Rio)   0.9
# Portland State University   0.8
# Université du Québec   0.9
# University of Regina   0.9
# Ryerson University   0.9
# Universiti Sains Malaysia   0.9
# University of Salamanca   0.9
# University of Salento   0.9
# University of Santiago de Compostela   0.7
# University of Sassari   0.9
# Savitribai Phule Pune University   0.9
# Shahid Beheshti University of Medical Sciences   0.7
# University of Sharjah   0.9
# Université de Sherbrooke   0.9
# Shiraz University of Technology   0.9
# Sichuan University   0.9
# Sidi Mohamed Ben Abdellah University   0.9
# University of South Dakota   0.9
# Southern Cross University   0.8
# University of the Sunshine Coast   0.9
# University of Tabriz   0.9
# University of Tehran   0.9
# Universiti Teknologi Malaysia   0.9
# Texas Tech University   0.7
# University of Thessaly   0.9
# Tokyo Metropolitan University   0.9
# University of Tours   0.8
# TU Braunschweig   0.9
# University of Ulsan   0.8
# Ulster University   0.9
# University of Warsaw   0.6
# 699.0
# Waseda University   0.9
# University of Westminster   0.9
# Adam Mickiewicz University   0.9
# University of the Aegean   0.8
# Aichi Medical University   0.9
# Ajou University   0.8
# Aligarh Muslim University   0.9
# American University in Cairo   0.9
# American University of Sharjah   0.9
# Athens University of Economics and Business   0.9
# University of Baghdad   0.8
# Bauman Moscow State Technical University   0.9
# Beijing Jiaotong University   0.8
# Benha University   0.9
# University of Brasília   0.9
# University of Cadiz   0.9
# Chang Gung University   0.9
# China University of Geosciences   0.9
# China University of Geosciences   0.5
# 699.0
# China University of Mining and Technology   0.8
# University of Córdoba   0.9
# University of Deusto   0.9
# Embry-Riddle Aeronautical University   0.9
# Federal University of Rio de Janeiro   0.9
# Ferdowsi University of Mashhad   0.9
# University of La Frontera   0.9
# Fuzhou University   0.9
# Hyogo College of Medicine   0.9
# Indian Institute of Technology (Indian School of Mines) Dhanbad   0.8
# Inha University   0.9
# University of Isfahan   0.9
# Jadavpur University   0.9
# University of Jaén   0.9
# Jeonbuk National University   0.9
# Jiangsu University   0.9
# Jilin University   0.8
# Jinan University   0.9
# Kanazawa University   0.8
# Kaohsiung Medical University   0.8
# K.N. Toosi University of Technology   0.9
# Kumamoto University   0.9
# University of Kurdistan   0.9
# University of Las Palmas de Gran Canaria   0.8
# Louisiana Tech University   0.8
# Mississippi State University   0.9
# Muroran Institute of Technology   0.9
# University of Nairobi   0.9
# Nanjing Agricultural University   0.8
# National Institute of Technology Rourkela   0.6
# 699.0
# National Institute of Technology   0.9
# National University of Sciences and Technology   0.9
# Niigata University   0.9
# Normandy University   0.9
# Northeastern University   0.09999999999999998
# 699.0
# University of Northern British Columbia (UNBC)   0.9
# Northwest University   0.9
# Polytechnic Institute of Porto   0.9
# Polytechnic University of Valencia   0.9
# Pontifical Catholic University of Rio Grande do Sul (PUCRS)   0.9
# University of Puerto Rico   0.9
# University of the Punjab   0.9
# Rikkyo University   0.9
# Rochester Institute of Technology   0.9
# Université Saint-Joseph de Beyrouth   0.9
# Saint-Petersburg Mining University   0.9
# University of Salford   0.9
# São Paulo State University (UNESP)   0.9
# University of Science and Technology Beijing   0.9
# University of Seoul   0.7
# University of Seville   0.8
# Shahid Beheshti University   0.9
# Shanghai University   0.9
# Shanghai University of Finance and Economics (SUFE)   0.9
# Shanghai Maritime University   0.9
# Sheffield Hallam University   0.9
# Sogang University   0.9
# University of South Bohemia in České Budějovice   0.7
# St Marianna University School of Medicine   0.9
# Tallinn University of Technology   0.9
# Tanta University   0.9
# Teesside University   0.9
# University of Texas at El Paso   0.8
# Tezpur University   0.9
# Tokyo University of Agriculture and Technology   0.9
# Tshwane University of Technology   0.9
# Universiti Utara Malaysia   0.9
# VIT University   0.8
# University of Wolverhampton   0.9
# Wuhan University of Technology   0.9
# Xiangtan University   0.9
# Xidian University   0.9
# Yangzhou University   0.8
# Yeungnam University   0.9
# University of Zaragoza   0.8
# Akita University   0.9
# Alexandria University   0.9
# University of the Andes   0.8
# University of the Andes   0.8
# Anna University   0.9
# Bahauddin Zakariya University   0.9
# Birla Institute of Technology and Science   0.9
# Bu-Ali Sina University   0.9
# Canterbury Christ Church University   0.9
# Chuo University   0.9
# University of Concepción   0.9
# Czech University of Life Sciences Prague (CULS)   0.9
# Delhi Technological University   0.9
# Edge Hill University   0.6
# 699.0
# The University of Electro-Communications   0.9
# Erciyes University   0.9
# Fayoum University   0.9
# Federal University of Bahia   0.9
# Federal University of Ceará (UFC)   0.9
# Federal University of Health Sciences of Porto Alegre (UFCSPA)   0.9
# Federal University of Lavras   0.9
# Federal University of Pernambuco   0.9
# Federal University of Santa Maria   0.9
# Federal University of São Carlos   0.9
# Federal University of Viçosa   0.9
# University of Fortaleza (UNIFOR)   0.9
# Guangxi University   0.9
# Gunma University   0.9
# University of Hyogo   0.9
# Industrial University of Santander (UIS)   0.9
# Kagoshima University   0.9
# Kharazmi University   0.9
# Kyoto Institute of Technology   0.8
# University of León   0.9
# University of Lethbridge   0.9
# Maharaja Sayajirao University of Baroda   0.9
# Manipal Academy of Higher Education   0.9
# University of Manouba   0.9
# Marmara University   0.9
# Mie University   0.9
# Nagasaki University   0.9
# Nanjing University of Aeronautics and Astronautics   0.9
# National Chung Hsing University   0.8
# National University of Colombia   0.9
# National University of San Martín   0.9
# National Taipei University   0.9
# National Yunlin University of Science and Technology   0.9
# Oakland University   0.9
# Ocean University of China   0.9
# Osaka Medical College   0.9
# University of Peshawar   0.9
# PSG College of Technology   0.9
# Saga University   0.9
# Semnan University   0.9
# Shahed University   0.9
# Shahrekord University   0.9
# Shimane University   0.9
# Shinshu University   0.9
# Shizuoka University   0.9
# University of Shizuoka   0.9
# Siksha ‘O’ Anusandhan   0.9
# Slovak University of Technology in Bratislava   0.9
# University of South China   0.9
# Southern Medical University   0.9
# Southwest Jiaotong University   0.9
# Taras Shevchenko National University of Kyiv   0.9
# TOBB University of Economics and Technology   0.9
# Tokyo University of Marine Science and Technology   0.9
# Tomas Bata University in Zlín   0.9
# Toyohashi University of Technology (TUT)   0.8
# Tribhuvan University   0.7
# University of Tunis El Manar   0.7
# Ufa State Aviation Technical University   0.9
# Urmia University   0.9
# Yamagata University   0.9
# Yazd University   0.9
# Yokohama National University   0.9
# University of Zagreb   0.9
# University of Zanjan   0.9
#
#
# Mismatch: 558 / 1397  ( 39.94273443092341 )
#
#
#
# Synthetic_0
# 47   0.6666666666666667
# 1000.5
# 100   0.6666666666666667
# 1000.5
# 169   0.6666666666666667
# 1000.5
# 284   0.6666666666666667
# 1000.5
# 450   0.6666666666666667
# 1000.5
# 461   0.6666666666666667
# 1000.5
# 755   0.6666666666666667
# 1000.5
# 901   0.6666666666666667
# 1000.5
# 1267   0.6666666666666667
# 1000.5
# 1380   0.6666666666666667
# 1000.5
# 1502   0.6666666666666667
# 1000.5
# 1624   0.6666666666666667
# 1000.5
# 1931   0.6666666666666667
# 1000.5
# 1969   0.6666666666666667
# 1000.5
#
#
# Mismatch: 14 / 2000  ( 0.7000000000000001 )
#
#
#
# Synthetic_1
# 5   0.6666666666666667
# 1000.5
# 6   0.6666666666666667
# 1000.5
# 16   0.6666666666666667
# 1000.5
# 22   0.6666666666666667
# 1000.5
# 29   0.6666666666666667
# 1000.5
# 40   0.6666666666666667
# 1000.5
# 46   0.6666666666666667
# 1000.5
# 50   0.6666666666666667
# 1000.5
# 96   0.6666666666666667
# 1000.5
# 128   0.6666666666666667
# 1000.5
# 131   0.6666666666666667
# 1000.5
# 135   0.6666666666666667
# 1000.5
# 148   0.6666666666666667
# 1000.5
# 160   0.6666666666666667
# 1000.5
# 205   0.6666666666666667
# 1000.5
# 307   0.6666666666666667
# 1000.5
# 325   0.6666666666666667
# 1000.5
# 329   0.6666666666666667
# 1000.5
# 334   0.6666666666666667
# 1000.5
# 345   0.6666666666666667
# 1000.5
# 355   0.6666666666666667
# 1000.5
# 389   0.6666666666666667
# 1000.5
# 401   0.6666666666666667
# 1000.5
# 412   0.6666666666666667
# 1000.5
# 436   0.6666666666666667
# 1000.5
# 464   0.6666666666666667
# 1000.5
# 468   0.6666666666666667
# 1000.5
# 484   0.6666666666666667
# 1000.5
# 489   0.6666666666666667
# 1000.5
# 508   0.6666666666666667
# 1000.5
# 524   0.6666666666666667
# 1000.5
# 540   0.6666666666666667
# 1000.5
# 559   0.6666666666666667
# 1000.5
# 589   0.6666666666666667
# 1000.5
# 605   0.6666666666666667
# 1000.5
# 644   0.6666666666666667
# 1000.5
# 659   0.6666666666666667
# 1000.5
# 675   0.6666666666666667
# 1000.5
# 693   0.6666666666666667
# 1000.5
# 707   0.6666666666666667
# 1000.5
# 760   0.6666666666666667
# 1000.5
# 776   0.6666666666666667
# 1000.5
# 791   0.6666666666666667
# 1000.5
# 837   0.6666666666666667
# 1000.5
# 860   0.6666666666666667
# 1000.5
# 879   0.6666666666666667
# 1000.5
# 890   0.6666666666666667
# 1000.5
# 941   0.6666666666666667
# 1000.5
# 946   0.6666666666666667
# 1000.5
# 1081   0.6666666666666667
# 1000.5
# 1083   0.6666666666666667
# 1000.5
# 1190   0.6666666666666667
# 1000.5
# 1218   0.6666666666666667
# 1000.5
# 1253   0.6666666666666667
# 1000.5
# 1271   0.6666666666666667
# 1000.5
# 1274   0.6666666666666667
# 1000.5
# 1296   0.6666666666666667
# 1000.5
# 1297   0.6666666666666667
# 1000.5
# 1308   0.6666666666666667
# 1000.5
# 1317   0.6666666666666667
# 1000.5
# 1320   0.6666666666666667
# 1000.5
# 1359   0.6666666666666667
# 1000.5
# 1381   0.6666666666666667
# 1000.5
# 1389   0.6666666666666667
# 1000.5
# 1404   0.6666666666666667
# 1000.5
# 1451   0.6666666666666667
# 1000.5
# 1452   0.6666666666666667
# 1000.5
# 1457   0.6666666666666667
# 1000.5
# 1482   0.6666666666666667
# 1000.5
# 1495   0.6666666666666667
# 1000.5
# 1513   0.6666666666666667
# 1000.5
# 1561   0.6666666666666667
# 1000.5
# 1562   0.6666666666666667
# 1000.5
# 1571   0.6666666666666667
# 1000.5
# 1594   0.6666666666666667
# 1000.5
# 1595   0.6666666666666667
# 1000.5
# 1613   0.6666666666666667
# 1000.5
# 1635   0.6666666666666667
# 1000.5
# 1659   0.6666666666666667
# 1000.5
# 1664   0.6666666666666667
# 1000.5
# 1683   0.6666666666666667
# 1000.5
# 1726   0.6666666666666667
# 1000.5
# 1731   0.6666666666666667
# 1000.5
# 1741   0.6666666666666667
# 1000.5
# 1780   0.6666666666666667
# 1000.5
# 1788   0.6666666666666667
# 1000.5
# 1808   0.6666666666666667
# 1000.5
# 1822   0.6666666666666667
# 1000.5
# 1840   0.6666666666666667
# 1000.5
# 1841   0.6666666666666667
# 1000.5
# 1846   0.6666666666666667
# 1000.5
# 1853   0.6666666666666667
# 1000.5
# 1944   0.6666666666666667
# 1000.5
# 1982   0.6666666666666667
# 1000.5
# 1995   0.6666666666666667
# 1000.5
# 1997   0.6666666666666667
# 1000.5
#
#
# Mismatch: 96 / 2000  ( 4.8 )
#
#
#
# Synthetic_2
# 1   0.6666666666666667
# 1000.5
# 8   0.6666666666666667
# 1000.5
# 9   0.6666666666666667
# 1000.5
# 10   0.6666666666666667
# 1000.5
# 38   0.6666666666666667
# 1000.5
# 67   0.6666666666666667
# 1000.5
# 68   0.6666666666666667
# 1000.5
# 113   0.6666666666666667
# 1000.5
# 117   0.6666666666666667
# 1000.5
# 125   0.6666666666666667
# 1000.5
# 130   0.6666666666666667
# 1000.5
# 138   0.6666666666666667
# 1000.5
# 147   0.6666666666666667
# 1000.5
# 157   0.6666666666666667
# 1000.5
# 166   0.6666666666666667
# 1000.5
# 167   0.6666666666666667
# 1000.5
# 179   0.6666666666666667
# 1000.5
# 257   0.6666666666666667
# 1000.5
# 287   0.6666666666666667
# 1000.5
# 294   0.6666666666666667
# 1000.5
# 312   0.6666666666666667
# 1000.5
# 313   0.6666666666666667
# 1000.5
# 333   0.6666666666666667
# 1000.5
# 411   0.6666666666666667
# 1000.5
# 432   0.6666666666666667
# 1000.5
# 446   0.6666666666666667
# 1000.5
# 453   0.6666666666666667
# 1000.5
# 476   0.6666666666666667
# 1000.5
# 493   0.6666666666666667
# 1000.5
# 536   0.6666666666666667
# 1000.5
# 560   0.6666666666666667
# 1000.5
# 568   0.6666666666666667
# 1000.5
# 570   0.6666666666666667
# 1000.5
# 581   0.6666666666666667
# 1000.5
# 585   0.6666666666666667
# 1000.5
# 590   0.6666666666666667
# 1000.5
# 661   0.6666666666666667
# 1000.5
# 668   0.6666666666666667
# 1000.5
# 670   0.6666666666666667
# 1000.5
# 676   0.6666666666666667
# 1000.5
# 704   0.6666666666666667
# 1000.5
# 734   0.6666666666666667
# 1000.5
# 752   0.6666666666666667
# 1000.5
# 765   0.6666666666666667
# 1000.5
# 787   0.6666666666666667
# 1000.5
# 813   0.6666666666666667
# 1000.5
# 830   0.6666666666666667
# 1000.5
# 889   0.6666666666666667
# 1000.5
# 900   0.6666666666666667
# 1000.5
# 912   0.6666666666666667
# 1000.5
# 913   0.6666666666666667
# 1000.5
# 916   0.6666666666666667
# 1000.5
# 917   0.6666666666666667
# 1000.5
# 921   0.6666666666666667
# 1000.5
# 928   0.6666666666666667
# 1000.5
# 929   0.6666666666666667
# 1000.5
# 964   0.6666666666666667
# 1000.5
# 965   0.6666666666666667
# 1000.5
# 970   0.6666666666666667
# 1000.5
# 973   0.6666666666666667
# 1000.5
# 1021   0.6666666666666667
# 1000.5
# 1028   0.6666666666666667
# 1000.5
# 1042   0.6666666666666667
# 1000.5
# 1064   0.6666666666666667
# 1000.5
# 1079   0.6666666666666667
# 1000.5
# 1118   0.6666666666666667
# 1000.5
# 1145   0.6666666666666667
# 1000.5
# 1205   0.6666666666666667
# 1000.5
# 1206   0.6666666666666667
# 1000.5
# 1209   0.6666666666666667
# 1000.5
# 1214   0.6666666666666667
# 1000.5
# 1241   0.6666666666666667
# 1000.5
# 1370   0.6666666666666667
# 1000.5
# 1377   0.6666666666666667
# 1000.5
# 1438   0.6666666666666667
# 1000.5
# 1487   0.6666666666666667
# 1000.5
# 1511   0.6666666666666667
# 1000.5
# 1535   0.6666666666666667
# 1000.5
# 1546   0.6666666666666667
# 1000.5
# 1559   0.6666666666666667
# 1000.5
# 1602   0.6666666666666667
# 1000.5
# 1610   0.6666666666666667
# 1000.5
# 1639   0.6666666666666667
# 1000.5
# 1657   0.6666666666666667
# 1000.5
# 1695   0.6666666666666667
# 1000.5
# 1715   0.6666666666666667
# 1000.5
# 1773   0.6666666666666667
# 1000.5
# 1785   0.6666666666666667
# 1000.5
# 1819   0.6666666666666667
# 1000.5
# 1844   0.6666666666666667
# 1000.5
# 1879   0.6666666666666667
# 1000.5
# 1895   0.6666666666666667
# 1000.5
# 1901   0.6666666666666667
# 1000.5
# 1909   0.6666666666666667
# 1000.5
# 1949   0.6666666666666667
# 1000.5
# 1977   0.6666666666666667
# 1000.5
# 1978   0.6666666666666667
# 1000.5
# 1985   0.6666666666666667
# 1000.5
# 1989   0.6666666666666667
# 1000.5
#
#
# Mismatch: 99 / 2000  ( 4.95 )

# %%
df
